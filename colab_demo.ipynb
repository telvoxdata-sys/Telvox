# %% [markdown]
# # 🇳🇵 Chatterbox Nepali TTS Demo
#
# Fine-tuned Nepali text-to-speech with voice cloning.
#
# **Model**: [Imbatmann/chatterbox-nepali-tts](https://huggingface.co/Imbatmann/chatterbox-nepali-tts)
#
# ⚠️ Change runtime type to **T4 GPU** for best results: `Runtime → Change runtime type → T4 GPU`

# %%
# 📦 Install dependencies
# !pip install -q git+https://github.com/Imbatmann/chatterbox-nepali.git safetensors librosa
# Out:
#   error: subprocess-exited-with-error
#
#   × git clone --filter=blob:none --quiet https://github.com/Imbatmann/chatterbox-nepali.git /tmp/pip-req-build-xazyqkgs did not run successfully.
#   │ exit code: 128
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × git clone --filter=blob:none --quiet https://github.com/Imbatmann/chatterbox-nepali.git /tmp/pip-req-build-xazyqkgs did not run successfully.
# │ exit code: 128
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
import sys
import os

print("Downloading and installing chatterbox from GitHub source zip...")
# Try downloading the repository as a zip file to bypass git clone issues
zip_url = "https://github.com/Imbatmann/chatterbox-nepali/archive/refs/heads/master.zip" # Changed 'main' to 'master'
repo_dir_name = "chatterbox-nepali-master" # Changed to reflect 'master' branch
zip_file_name = "chatterbox-nepali-master.zip" # Changed to reflect 'master' branch

# Removed -q to get more verbose output from wget
# !wget {zip_url} -O {zip_file_name}

# Check if download was successful
if os.path.exists(zip_file_name) and os.path.getsize(zip_file_name) > 0:
    print(f"Downloaded {zip_file_name}. Unzipping...")
    # !unzip -q -o {zip_file_name}
    if os.path.exists(repo_dir_name):
        print(f"Installing chatterbox from extracted directory: {repo_dir_name}")
        # !pip install ./{repo_dir_name} safetensors librosa
    else:
        print(f"Error: Extracted directory '{repo_dir_name}' not found.")
        # Fallback to find if the folder was extracted under a different name
        extracted_dirs = [d for d in os.listdir('.') if os.path.isdir(d) and d.startswith('chatterbox-nepali')]
        if extracted_dirs:
            print(f"Found alternative extracted directories: {extracted_dirs}. Trying to install from {extracted_dirs[0]}")
            # !pip install ./{extracted_dirs[0]} safetensors librosa
        else:
            print("No chatterbox-nepali directory found after unzipping.")
else:
    print(f"Error: Download of {zip_file_name} failed or resulted in an empty file.")


# 🤖 Load Model
import torch, torchaudio as ta
from chatterbox.mtl_tts import ChatterboxMultilingualTTS
from huggingface_hub import hf_hub_download
from safetensors.torch import load_file
from IPython.display import Audio, display

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# Load base model
model = ChatterboxMultilingualTTS.from_pretrained(device)

# Load Nepali fine-tuned weights
ckpt = hf_hub_download("Imbatmann/chatterbox-nepali-tts", "t3_mtl_nepali_final.safetensors")
sd = load_file(ckpt)
cleaned = {k.replace("patched_model.", "").replace("model.", ""): v for k, v in sd.items()}
model.t3.load_state_dict(cleaned, strict=False)
model.t3.to(device).eval()
print("✅ Model loaded!")
# Out:
# Downloading and installing chatterbox from GitHub source zip...
# --2026-04-13 08:05:12--  https://github.com/Imbatmann/chatterbox-nepali/archive/refs/heads/master.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2026-04-13 08:05:12 ERROR 404: Not Found.
#
# Error: Download of chatterbox-nepali-master.zip failed or resulted in an empty file.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_6958/3569702798.py in <cell line: 0>()
#      33 # 🤖 Load Model
#      34 import torch, torchaudio as ta
# ---> 35 from chatterbox.mtl_tts import ChatterboxMultilingualTTS
#      36 from huggingface_hub import hf_hub_download
#      37 from safetensors.torch import load_file
#
# ModuleNotFoundError: No module named 'chatterbox'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# 🎤 Download reference audio
# !wget -q https://huggingface.co/Imbatmann/chatterbox-nepali-tts/resolve/main/ref.wav -O ref.wav
print("✅ Reference audio downloaded")
display(Audio("ref.wav"))

# %%
# 🗣️ Generate Nepali Speech
text = "नमस्ते, म नेपाली एआई हुँ। मलाई तपाईंसँग कुरा गर्न पाउँदा खुसी लागेको छ।"
print(f"Generating: {text}")

wav = model.generate(
    text=text,
    language_id="ne",
    audio_prompt_path="ref.wav",
    exaggeration=0.5,
    temperature=0.8,
)

ta.save("output.wav", wav, model.sr)
print(f"✅ Generated: {wav.shape[1]/model.sr:.1f}s of audio")
display(Audio("output.wav"))

# %%
# 🔁 Try different texts
texts = [
    "नेपाल हिमाल, पहाड र तराईले भरिएको सुन्दर देश हो।",
    "काठमाडौं उपत्यकाको ऐतिहासिक र सांस्कृतिक महत्त्व धेरै ठूलो छ।",
    "नेपाली भाषा धेरै मीठो र गम्भीर छ।",
]

for i, txt in enumerate(texts):
    print(f"Generating: {txt}")
    w = model.generate(txt, "ne", audio_prompt_path="ref.wav", exaggeration=0.5, temperature=0.8)
    ta.save(f"output_{i}.wav", w, model.sr)
    print(f"✅ output_{i}.wav — {w.shape[1]/model.sr:.1f}s")
    display(Audio(f"output_{i}.wav"))

# %%
# 🎙️ Clone YOUR voice!
# Upload a 5-10 second audio file, then run this cell
from google.colab import files
uploaded = files.upload()  # Select your .wav or .mp3 file
my_voice_path = list(uploaded.keys())[0]

text = "यो मेरो आवाजमा बोलिएको नेपाली वाक्य हो।"
wav = model.generate(text, "ne", audio_prompt_path=my_voice_path, exaggeration=0.5, temperature=0.8)
ta.save("my_voice_output.wav", wav, model.sr)
print(f"✅ Cloned voice: {wav.shape[1]/model.sr:.1f}s")
display(Audio("my_voice_output.wav"))
